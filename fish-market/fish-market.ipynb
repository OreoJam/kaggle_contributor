# %%
# Import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read Data

# %%
# Get data
df = pd.read_csv('data/Fish.csv')

# %%
df
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %% [markdown]
# ### Meaning
# - Species: species name of fish
# - Weight: weight of fish in Gram g
# - Length1: vertical length in cm
# - Length2: diagonal length in cm
# - Length3: cross length in cm
# - Height: height in cm
# - Width: diagonal width in cm

# %% [markdown]
# ### Changing names

# %%
df.rename(columns={'Length1':'LenVertical', 'Length2':'LenDiagonal', 'Length3':'LenCross'}, inplace=True)
df
# Out:
#     Species  Weight  LenVertical  LenDiagonal  LenCross   Height   Width
# 0     Bream   242.0         23.2         25.4      30.0  11.5200  4.0200
# 1     Bream   290.0         24.0         26.3      31.2  12.4800  4.3056
# 2     Bream   340.0         23.9         26.5      31.1  12.3778  4.6961
# 3     Bream   363.0         26.3         29.0      33.5  12.7300  4.4555
# 4     Bream   430.0         26.5         29.0      34.0  12.4440  5.1340
# ..      ...     ...          ...          ...       ...      ...     ...
# 154   Smelt    12.2         11.5         12.2      13.4   2.0904  1.3936
# 155   Smelt    13.4         11.7         12.4      13.5   2.4300  1.2690
# 156   Smelt    12.2         12.1         13.0      13.8   2.2770  1.2558
# 157   Smelt    19.7         13.2         14.3      15.2   2.8728  2.0672
# 158   Smelt    19.9         13.8         15.0      16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %% [markdown]
# ### Overview

# %%
df.describe()
# Out:
#             Weight  LenVertical  LenDiagonal    LenCross      Height  \
# count   159.000000   159.000000   159.000000  159.000000  159.000000
# mean    398.326415    26.247170    28.415723   31.227044    8.970994
# std     357.978317     9.996441    10.716328   11.610246    4.286208
# min       0.000000     7.500000     8.400000    8.800000    1.728400
# 25%     120.000000    19.050000    21.000000   23.150000    5.944800
# 50%     273.000000    25.200000    27.300000   29.400000    7.786000
# 75%     650.000000    32.700000    35.500000   39.650000   12.365900
# max    1650.000000    59.000000    63.400000   68.000000   18.957000
#
#             Width
# count  159.000000
# mean     4.417486
# std      1.685804
# min      1.047600
# 25%      3.385650
# 50%      4.248500
# 75%      5.584500
# max      8.142000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Species      159 non-null    object
#  1   Weight       159 non-null    float64
#  2   LenVertical  159 non-null    float64
#  3   LenDiagonal  159 non-null    float64
#  4   LenCross     159 non-null    float64
#  5   Height       159 non-null    float64
#  6   Width        159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
# check null item
df.isnull().sum()
# Out:
# Species        0
# Weight         0
# LenVertical    0
# LenDiagonal    0
# LenCross       0
# Height         0
# Width          0
# dtype: int64

# %% [markdown]
# ### Investigating data

# %%
sns.set_palette('deep')
df.hist(figsize=(12, 12))
# Out:
# array([[<AxesSubplot:title={'center':'Weight'}>,
#         <AxesSubplot:title={'center':'LenVertical'}>],
#        [<AxesSubplot:title={'center':'LenDiagonal'}>,
#         <AxesSubplot:title={'center':'LenCross'}>],
#        [<AxesSubplot:title={'center':'Height'}>,
#         <AxesSubplot:title={'center':'Width'}>]], dtype=object)

# %%
# number of Species
df['Species'].value_counts()
# Out:
# Perch        56
# Bream        35
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# Name: Species, dtype: int64

# %%
# histogram by Species
sns.set_palette('deep')
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Species')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Count'>

# %%
# scatterplot for Height and Weight
sns.set_palette('deep')
plt.figure(figsize=(12, 7))
sns.scatterplot(x='Height', y='Weight', data=df, hue='Species', style='Species', s=60)
plt.show()

# %%
# scatterplot for Height and LenVertical (Length of Vertical)
sns.set_palette('deep')
plt.figure(figsize=(12, 7))
sns.scatterplot(x='LenVertical', y='Weight', data=df, hue='Species', style='Species', s=60)
plt.show()

# %%
# scatterplot for Height and LenDiagonal (Length of Diagonal)
sns.set_palette('deep')
plt.figure(figsize=(12, 7))
sns.scatterplot(x='LenDiagonal', y='Weight', data=df, hue='Species', style='Species', s=60)
plt.show()

# %%
# scatterplot for Height and LenCross (Length of Cross)
sns.set_palette('deep')
plt.figure(figsize=(12, 7))
sns.scatterplot(x='LenCross', y='Weight', data=df, hue='Species', style='Species', s=60)
plt.show()

# %%
# scatterplot for Height and Width
sns.set_palette('deep')
plt.figure(figsize=(12, 7))
sns.scatterplot(x='Width', y='Weight', data=df, hue='Species', style='Species', s=60)
plt.show()

# %%
# correlation
sns.set_palette('deep')
plt.figure(figsize=(12, 7))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Preprocessing

# %%
# seperate input and target
target_data = df['Species']
input_data = df.drop('Species', axis=1)

# %%
target_data, input_data
# Out:
# (0      Bream
#  1      Bream
#  2      Bream
#  3      Bream
#  4      Bream
#         ...
#  154    Smelt
#  155    Smelt
#  156    Smelt
#  157    Smelt
#  158    Smelt
#  Name: Species, Length: 159, dtype: object,
#       Weight  LenVertical  LenDiagonal  LenCross   Height   Width
#  0     242.0         23.2         25.4      30.0  11.5200  4.0200
#  1     290.0         24.0         26.3      31.2  12.4800  4.3056
#  2     340.0         23.9         26.5      31.1  12.3778  4.6961
#  3     363.0         26.3         29.0      33.5  12.7300  4.4555
#  4     430.0         26.5         29.0      34.0  12.4440  5.1340
#  ..      ...          ...          ...       ...      ...     ...
#  154    12.2         11.5         12.2      13.4   2.0904  1.3936
#  155    13.4         11.7         12.4      13.5   2.4300  1.2690
#  156    12.2         12.1         13.0      13.8   2.2770  1.2558
#  157    19.7         13.2         14.3      15.2   2.8728  2.0672
# ...

# %%
# encording
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
target_data = encoder.fit_transform(target_data)
target_map = {index:label for index, label in enumerate(encoder.classes_)}
target_map
# Out:
# {0: 'Bream',
#  1: 'Parkki',
#  2: 'Perch',
#  3: 'Pike',
#  4: 'Roach',
#  5: 'Smelt',
#  6: 'Whitefish'}

# %%
# polynomial features
'''
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(include_bias=False)
poly.fit(input_data)
poly_input_data = poly.transform(input_data)
poly_input_data.shape
'''
# Out:
# (159, 27)

# %%
# standardize
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
ss.fit(input_data)
scaled_input_data = ss.transform(input_data)
scaled_input_data[:10]
# Out:
# array([[-0.43807217, -0.30578858, -0.28230301, -0.10602023,  0.59657867,
#         -0.23652895],
#        [-0.30356218, -0.22550724, -0.19805366, -0.00233668,  0.82126055,
#         -0.06657895],
#        [-0.16344761, -0.23554241, -0.17933159, -0.01097698,  0.79734129,
#          0.16579317],
#        [-0.09899491,  0.0053016 ,  0.05469437,  0.19639012,  0.87977146,
#          0.022621  ],
#        [ 0.08875862,  0.02537193,  0.05469437,  0.23959159,  0.81283498,
#          0.42637127],
#        [ 0.14480444,  0.05547743,  0.12022164,  0.30007366,  1.08395111,
#          0.30343125],
#        [ 0.28491901,  0.05547743,  0.12022164,  0.28279307,  1.21901769,
#          0.51235788],
#        [-0.02333304,  0.13575877,  0.14830475,  0.32599455,  0.86572884,
#          0.16216328],
#        [ 0.14480444,  0.13575877,  0.14830475,  0.33463485,  1.17815367,
#          0.25368398],
#        [ 0.28491901,  0.22607527,  0.21383202,  0.4296781 ,  1.23004114,
#          0.32247327]])

# %% [markdown]
# ### Training & Testing

# %%
# split train / test data
from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target = train_test_split(scaled_input_data, target_data, random_state=0)

# %%
test_input.shape, train_input.shape
# Out:
# ((40, 6), (119, 6))

# %%
# linear regression
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(train_input, train_target)
print(lr.score(train_input, train_target), lr.score(test_input, test_target))
# Out:
# 0.7266275733491456 0.4287563439159303

# %%
# logistic regression
from sklearn.linear_model import LogisticRegression
lgr = LogisticRegression()
lgr.fit(train_input, train_target)
print(lgr.score(train_input, train_target), lgr.score(test_input, test_target))
# Out:
# 0.8151260504201681 0.825

# %%
# decision tree
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(max_depth=13, random_state=0)
dt.fit(train_input, train_target)
print(dt.score(train_input, train_target), dt.score(test_input, test_target))
# Out:
# 1.0 0.725

# %%
# graph - decision tree
from sklearn.tree import plot_tree
plt.figure(figsize=(20, 15))
plot_tree(dt, filled=True, feature_names=['Weight', 'Height', 'LenVertical', 'LenDiagonal', 'LenCross', 'Width'])
plt.show()
